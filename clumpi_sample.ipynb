# %% [markdown]
# # Installation

# %%
# !pip install -U pip
# !pip install clumpi
#!pip install git+https://github.com/jniimi/clumpi.git
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.4 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.0.1
# Requirement already satisfied: clumpi in /usr/local/lib/python3.11/dist-packages (1.0.0)

# %% [markdown]
# # Import

# %%
import pandas as pd
import clumpi

# %% [markdown]
# # Load Sample Data

# %%
df = clumpi.load_sample_data()
display(df.head(5))
# Out:
#   user_id  t
# 0     Ava  1
# 1     Ava  2
# 2     Ava  4
# 3     Ava  5
# 4     Ava  7

# %% [markdown]
# # Calculate Clumpiness (takes a bit longer for the simulation)

# %%
RFC = clumpi.get_RFC(data=df, id='user_id', t='t', N=30)
display(RFC)
# Out:
#   user_id   R   F         H        H0  C
# 0     Ava   3  18  0.021723  0.075028  0
# 1   Chris   3  10  0.011294  0.162741  0
# 2    Jack   3  10  0.364854  0.162741  1
# 3    Jane  24   4  0.488938  0.335485  1
# 4   Smith   3   4  0.121458  0.335485  0

# %% [markdown]
# # Calculate H0 (Not a test but just a simulation)

# %%
clumpi.calc_threshold(N=30, M=3000, alpha=0.05)
# Out:
#      F            H0
# 0    1  7.944075e-01
# 1    2  5.243878e-01
# 2    3  3.945458e-01
# 3    4  3.426182e-01
# 4    5  2.880566e-01
# 5    6  2.492600e-01
# 6    7  2.254709e-01
# 7    8  2.025793e-01
# 8    9  1.776421e-01
# 9   10  1.696309e-01
# 10  11  1.483747e-01
# 11  12  1.382800e-01
# 12  13  1.227422e-01
# 13  14  1.118746e-01
# 14  15  1.002897e-01
# 15  16  9.105447e-02
# 16  17  8.392546e-02
# 17  18  7.502789e-02
# 18  19  6.541445e-02
# 19  20  5.942582e-02
# 20  21  5.082973e-02
# 21  22  4.464064e-02
# 22  23  3.734958e-02
# 23  24  3.042144e-02
# 24  25  2.836760e-02
# 25  26  2.259951e-02
# 26  27  1.478114e-02
# 27  28  1.176788e-02
# 28  29  3.507397e-03
# 29  30 -2.220446e-16

# %% [markdown]
# # Plot

# %%
clumpi.get_RFC(data=df, id='user_id', t='t', N=30, plot=True)
# Out:
#   user_id   R   F         H        H0  C
# 0     Ava   3  18  0.021723  0.073018  0
# 1   Chris   3  10  0.011294  0.162592  0
# 2    Jack   3  10  0.364854  0.162592  1
# 3    Jane  24   4  0.488938  0.339649  1
# 4   Smith   3   4  0.121458  0.339649  0
