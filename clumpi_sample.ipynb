# %% [markdown]
# # Installation

# %%
# %pip install git+https://github.com/jniimi/clumpi.git
# Out:
# Collecting git+https://github.com/jniimi/clumpi.git
#   Cloning https://github.com/jniimi/clumpi.git to /tmp/pip-req-build-wpqrnksv
#   Running command git clone --filter=blob:none --quiet https://github.com/jniimi/clumpi.git /tmp/pip-req-build-wpqrnksv
#   Resolved https://github.com/jniimi/clumpi.git to commit f3038d59c5a6f4fc5386c4220e29a330e517cf2f
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: clumpi
#   Building wheel for clumpi (setup.py) ... done
#   Created wheel for clumpi: filename=clumpi-0.0.1-py3-none-any.whl size=3375 sha256=a51d36259859c55f3fac189ac76ff9e551eb46cf3a644ccba8d70c3ce518b870
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eghc386t/wheels/3e/a0/ad/16bbbbbb752e6e3add0f7aeb07858ad3786e54414a675864ac
# Successfully built clumpi
# Installing collected packages: clumpi
# Successfully installed clumpi-0.0.1

# %% [markdown]
# # Import package

# %%
import clumpi

# %% [markdown]
# # Load sample data

# %%
df = clumpi.load_sample_data()
display(df.head(5))
# Out:
#   user_id  t
# 0     Ava  1
# 1     Ava  2
# 2     Ava  4
# 3     Ava  5
# 4     Ava  7

# %% [markdown]
# # Get Clumpiness

# %%
RFC = clumpi.get_RFC(data=df, id='user_id', t='t', N=30)
display(RFC)
# Out:
#   user_id   R   F         H        H0  C
# 0     Ava   3  18  0.021723  0.073792  0
# 1   Chris   3  10  0.011294  0.162592  0
# 2    Jack   3  10  0.364854  0.162592  1
# 3    Jane  24   4  0.488938  0.333256  1
