# %% [markdown]
# # Installation

# %%
# %pip install git+https://github.com/jniimi/clumpi.git
# Out:
# Collecting git+https://github.com/jniimi/clumpi.git
#   Cloning https://github.com/jniimi/clumpi.git to /tmp/pip-req-build-n3wxrq9k
#   Running command git clone --filter=blob:none --quiet https://github.com/jniimi/clumpi.git /tmp/pip-req-build-n3wxrq9k
#   Resolved https://github.com/jniimi/clumpi.git to commit 8e74899c82eb0974df75461d9e63f2582f536c46
#   Preparing metadata (setup.py) ... done

# %% [markdown]
# # Import package

# %%
import clumpi

# %% [markdown]
# # Load sample data

# %%
df = clumpi.load_sample_data()
display(df.head(5))
# Out:
#   user_id  t
# 0     Ava  1
# 1     Ava  2
# 2     Ava  4
# 3     Ava  5
# 4     Ava  7

# %% [markdown]
# # Get Clumpiness

# %%
RFC = clumpi.get_RFC(data=df, id='user_id', t='t', N=30)
display(RFC)
# Out:
#   user_id   R   F         H        H0  C
# 0     Ava   3  18  0.021723  0.073792  0
# 1   Chris   3  10  0.011294  0.162592  0
# 2    Jack   3  10  0.364854  0.162592  1
# 3    Jane  24   4  0.488938  0.333256  1

# %% [markdown]
# # Calculate H0 (Not a test but just a simulation)

# %%
clumpi.calc_threshold(N=30, M=3000, alpha=0.05)
# Out:
#      F            H0
# 0    1  7.944075e-01
# 1    2  4.990465e-01
# 2    3  4.205077e-01
# 3    4  3.332556e-01
# 4    5  2.880566e-01
# 5    6  2.581945e-01
# 6    7  2.271963e-01
# 7    8  2.066100e-01
# 8    9  1.807607e-01
# 9   10  1.627997e-01
# 10  11  1.491292e-01
# 11  12  1.331360e-01
# 12  13  1.227422e-01
# 13  14  1.118841e-01
# 14  15  1.002897e-01
# 15  16  9.105447e-02
# 16  17  8.392546e-02
# 17  18  7.377645e-02
# 18  19  6.541445e-02
# 19  20  5.942582e-02
# 20  21  5.082973e-02
# 21  22  4.464064e-02
# 22  23  3.734958e-02
# 23  24  3.042144e-02
# 24  25  2.836760e-02
# 25  26  1.747821e-02
# 26  27  1.478114e-02
# 27  28  1.176788e-02
# 28  29  3.507397e-03
# 29  30 -2.220446e-16
